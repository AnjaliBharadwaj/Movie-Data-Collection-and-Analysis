# %%
import pandas as pd
import requests

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                                  title  \
# 0        278               The Shawshank Redemption
# 1        238                          The Godfather
# 2        240                  The Godfather Part II
# 3        424                       Schindler's List
# 4        129                          Spirited Away
# ...      ...                                    ...
# 8555    9471        Charlie's Angels: Full Throttle
# 8556   76617                      Texas Chainsaw 3D
# 8557   37931                              MacGruber
# 8558   13761  Pocahontas II: Journey to a New World
# 8559  442064                             Proud Mary
#
#                                                overview release_date  \
# 0     Framed in the 1940s for the double murder of h...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# ...                                                 ...          ...
# 8555  The Angels are charged with finding a pair of ...   2003-06-27
# 8556  A young woman learns that she has inherited a ...   2013-01-03
# 8557  Ex-special operative MacGruber is called back ...   2010-05-21
# 8558  When news of John Smith's death reaches Americ...   1998-08-04
# 8559  Mary is a hit woman working for an organized c...   2018-01-12
#
#       popularity  vote_average  vote_count
# 0        133.097         8.704       25659
# 1        128.875         8.696       19504
# 2         74.991         8.577       11783
# 3         82.277         8.566       15161
# 4         83.588         8.539       15558
# ...          ...           ...         ...
# 8555      30.615         5.468        2879
# 8556      80.184         5.500        1589
# 8557      11.168         5.464         517
# 8558      18.471         5.464        1275
# 8559      12.701         5.462         474
#
# [8560 rows x 7 columns]
